// %%
import { openai } from '@ai-sdk/openai';
import { generateText } from 'ai';

const responseMessage = await generateText({
  model: openai('gpt-5-nano'),
  prompt: 'What is 345 x 678?',
});

const { md, display } = Deno.jupyter;

//await display(responseMessage);

md`# The answer is ${responseMessage.text}`;
// Out:
// # The answer is 233,910
//
// (345 × 678 = 345×600 + 345×70 + 345×8 = 207,000 + 24,150 + 2,760 = 233,910.)
